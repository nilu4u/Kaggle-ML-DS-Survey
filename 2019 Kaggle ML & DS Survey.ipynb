# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
responses = pd.read_csv("/Users/nilanjansahu/Downloads/Machine_Learning/2019 Kaggle ML & DS Survey/multiple_choice_responses.csv")
others = pd.read_csv("/Users/nilanjansahu/Downloads/Machine_Learning/2019 Kaggle ML & DS Survey/other_text_responses.csv")
questions = pd.read_csv("/Users/nilanjansahu/Downloads/Machine_Learning/2019 Kaggle ML & DS Survey/questions_only.csv")

# %%
responses.head()
# Out:
#   Time from Start to Finish (seconds)                           Q1  \
# 0               Duration (in seconds)  What is your age (# years)?
# 1                                 510                        22-24
# 2                                 423                        40-44
# 3                                  83                        55-59
# 4                                 391                        40-44
#
#                                        Q2  \
# 0  What is your gender? - Selected Choice
# 1                                    Male
# 2                                    Male
# 3                                  Female
# 4                                    Male
#
#                                        Q2_OTHER_TEXT  \
# 0  What is your gender? - Prefer to self-describe...
# 1                                                 -1
# 2                                                 -1
# 3                                                 -1
# ...

# %%
responses.shape
# Out:
# (19718, 246)

# %%
others.shape
# Out:
# (19718, 28)

# %%
responses = responses.iloc[1:,:]

# %%
responses.head()
# Out:
#   Time from Start to Finish (seconds)     Q1      Q2 Q2_OTHER_TEXT         Q3  \
# 1                                 510  22-24    Male            -1     France
# 2                                 423  40-44    Male            -1      India
# 3                                  83  55-59  Female            -1    Germany
# 4                                 391  40-44    Male            -1  Australia
# 5                                 392  22-24    Male            -1      India
#
#                     Q4                 Q5 Q5_OTHER_TEXT                    Q6  \
# 1      Master’s degree  Software Engineer            -1  1000-9,999 employees
# 2  Professional degree  Software Engineer            -1    > 10,000 employees
# 3  Professional degree                NaN            -1                   NaN
# 4      Master’s degree              Other             0    > 10,000 employees
# 5    Bachelor’s degree              Other             1        0-49 employees
#
# ...

# %%
#countries that participated
countries = responses['Q3'].value_counts().reset_index()

# %%
countries = countries.rename({'index':'Countries', 'Q3':'Participants'}, axis='columns')

# %%
countries
# Out:
#                                             Countries  Participants
# 0                                               India          4786
# 1                            United States of America          3085
# 2                                               Other          1054
# 3                                              Brazil           728
# 4                                               Japan           673
# 5                                              Russia           626
# 6                                               China           574
# 7                                             Germany           531
# 8   United Kingdom of Great Britain and Northern I...           482
# 9                                              Canada           450
# 10                                              Spain           399
# 11                                            Nigeria           395
# 12                                             France           387
# ...

# %%
#we will do our study on participation of top 30 countries except others

countries_top_31 = countries.iloc[:31,0].astype(str)

# %%
countries_top_31
# Out:
# 0                                                 India
# 1                              United States of America
# 2                                                 Other
# 3                                                Brazil
# 4                                                 Japan
# 5                                                Russia
# 6                                                 China
# 7                                               Germany
# 8     United Kingdom of Great Britain and Northern I...
# 9                                                Canada
# 10                                                Spain
# 11                                              Nigeria
# 12                                               France
# 13                                               Taiwan
# 14                                               Turkey
# 15                                                Italy
# 16                                            Australia
# ...

# %%
responses['Q3'] = responses['Q3'].astype(str)

# %%
responses['Q3']
# Out:
# 1                          France
# 2                           India
# 3                         Germany
# 4                       Australia
# 5                           India
# 6                          France
# 7                           India
# 8        United States of America
# 9        United States of America
# 10                    Netherlands
# 11                          India
# 12                        Germany
# 13                        Germany
# 14       United States of America
# 15                          India
# 16       United States of America
# 17                      Australia
# 18                          India
# 19                         France
# 20                         France
# 21                        Ireland
# 22       United States of America
# 23                          India
# 24                         Russia
# 25                         Greece
# 26                         Greece
# 27                          India
# ...

# %%
responses_top_31 = pd.DataFrame()
for i,country in enumerate(responses['Q3']):
    if country in countries_top_31:
        responses_top_31.append(responses[i])

# %%
responses_top_31
# Out:
# Empty DataFrame
# Columns: []
# Index: []
